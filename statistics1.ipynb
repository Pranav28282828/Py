# %%
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as stats

# %%
data=[15,16,16,17,17,17,18,18,19]
sns.histplot(data, color="red",kde=True)
plt.show()

# %%
print(stats.mean(data))
print(stats.median(data))
print(stats.mode(data))
# Out:
# 17
# 17
# 17

# %%
data1=[10,10,10,11,12]
sns.histplot(data1,color="blue",kde=True)
plt.show()

# %%
print(stats.mean(data1))
print(stats.median(data1))
print(stats.mode(data1))
# Out:
# 10.6
# 10
# 10
