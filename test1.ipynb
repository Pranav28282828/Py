# %%
import numpy as np
data=[5,2,7,8,5,9,1,3,5]

np.sort(data)
# Out:
# array([1, 2, 3, 5, 5, 5, 7, 8, 9])

# %%
import random
population=[23,45,67,43,35,8,45,,79,324,68,89,46,34,68,79,89,67]
len(population)
# Out:
#   Cell In[1], line 2
#     population=[23,45,67,43,35,8,45,,79,324,68,89,46,34,68,79,89,67]
#                                     ^
# SyntaxError: invalid syntax
